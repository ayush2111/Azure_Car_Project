# %% [markdown]
# # Create Catalog

# %%
# %sql
CREATE CATALOG car_catalog

# %% [markdown]
# # Create Schema

# %%
# %sql
CREATE SCHEMA cars_catalog.silver

# %%
# %sql
CREATE SCHEMA cars_catalog.gold
